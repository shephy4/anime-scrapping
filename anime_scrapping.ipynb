# %%
import requests
import urllib.request
import time
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os

# %%
i = 1

# %%
source = requests.get('https://www.creativeshrimp.com').text
source
# Out:
# '\ufeff<!DOCTYPE html>\n<!--[if IE 8]>\n<html id="ie8" lang="en-US">\n<![endif]-->\n<!--[if !(IE 8) ]><!-->\n<html lang="en-US">\n<!--<![endif]-->\n<head>\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<link rel="profile" href="http://gmpg.org/xfn/11" />\n<link rel="pingback" href="https://www.creativeshrimp.com/xmlrpc.php" />\n\n<!--[if lt IE 9]>\n<script src="https://www.creativeshrimp.com/wp-content/themes/litemag/assets/js/html5shiv.js"></script>\n<script src="https://www.creativeshrimp.com/wp-content/themes/litemag/assets/js/respond.min.js"></script>\n<![endif]-->\n\n\n<!-- This section is created with the SZ-Google for WordPress plugin 1.9.0 -->\n<!-- ===================================================================== -->\n<!-- ===================================================================== -->\n\n\t<!-- This site is optimized with the Yoast SEO plugin v14.0.1 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Cr
# ...

# %%
soup = bs4.BeautifulSoup(source, 'html.parser')
soup
# Out:
# ﻿<!DOCTYPE html>
#
# <!--[if IE 8]>
# <html id="ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 8) ]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.creativeshrimp.com/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
# <script src="https://www.creativeshrimp.com/wp-content/themes/litemag/assets/js/html5shiv.js"></script>
# <script src="https://www.creativeshrimp.com/wp-content/themes/litemag/assets/js/respond.min.js"></script>
# <![endif]-->
# <!-- This section is created with the SZ-Google for WordPress plugin 1.9.0 -->
# <!-- ===================================================================== -->
# <!-- ===================================================================== -->
# <!-- This site is optimized with the Yoast SEO plugin v14.0.1 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
match = soup.title.text
print(match)
# Out:
# Creative Shrimp • CG Tutorials, art and coffee for 3D Artists

# %%
for img in soup.find_all('img'):
    print(img)
# Out:
# <img alt="Creative Shrimp" class="big-logo" src="https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo.png"/>
# <img alt="Creative Shrimp" class="mini-logo" src="https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo-small.png"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/04/glitch-thumbnail_01_2-900x430.jpg"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/03/thumbnail_01_2-400x190.jpg"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/03/3drender_review_thumbnail_01_1-400x190.jpg"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/03/vlog_march_2020_thumbnail_01-400x190.jpg"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/03/blender_viewport_thumbnail_v3_01b-400x190.jpg"/>
# <img alt="" src="https://www.creativeshrimp.com/wp-content/uploads/2020/02/blender_viewport_thumbnail_v2_01-400x190.jpg"/>
# ...

# %%
for img in soup.find_all('img'):
    print(img.get('src'))
# Out:
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo.png
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo-small.png
# https://www.creativeshrimp.com/wp-content/uploads/2020/04/glitch-thumbnail_01_2-900x430.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/thumbnail_01_2-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/3drender_review_thumbnail_01_1-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/vlog_march_2020_thumbnail_01-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/blender_viewport_thumbnail_v3_01b-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/blender_viewport_thumbnail_v2_01-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/viewport_thumbnail_01_1a-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/quiz_thumbnail_01_1-400x190.jpg
# ...

# %%
name_b = img.get('alt')
if len(name_b) == 0:
    filename = str(i)
    i = i+1
else:
    filename = name_b

# %%
for img in soup.find_all('img'):
    b = img.get('src')
    if b[:1]=="/":
        image = "https://www.creativeshrimp.com" + b
    else:
        image = b
    print(image)
    name_b = img.get('alt')
if len(name_b) == 0:
    print(f'1  {name_b}')
    filename = str(i)
    imagefile = open(filename + '.jpeg', 'wb')
    i = i+1
else:
    print(f'2  {name_b}')
    filename =  str(name_b)
    imagefile = open(filename + '.jpeg', 'wb')
#wb mean write back, you can either use readonly or write back, read about it to understand more
imagefile.write(urllib.request.urlopen(image).read())
imagefile.close()
# Out:
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo.png
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo-small.png
# https://www.creativeshrimp.com/wp-content/uploads/2020/04/glitch-thumbnail_01_2-900x430.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/thumbnail_01_2-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/3drender_review_thumbnail_01_1-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/vlog_march_2020_thumbnail_01-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/blender_viewport_thumbnail_v3_01b-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/blender_viewport_thumbnail_v2_01-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/viewport_thumbnail_01_1a-400x190.jpg
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/quiz_thumbnail_01_1-400x190.jpg
# ...

# %%
i=1
for img in soup.find_all('img'):
    b = img.get('src')
    if b[:1]=="/":
        image = "https://www.creativeshrimp.com"+b
    else:
        image = b
    print(image)
    name_b = img.get('alt')
    if len(name_b)==0:
        print(f'1 --> {name_b}')
        filename=str(i)
        imagefile = open(filename+'.jpeg','wb')
        i=i+1
    else:
        print(f'2 --> {name_b}')
        filename=str(name_b)
        imagefile = open(filename+'.jpeg','wb')
    
    imagefile.write(urllib.request.urlopen(image).read())
    imagefile.close()
# Out:
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo.png
# 2 --> Creative Shrimp
# https://www.creativeshrimp.com/wp-content/uploads/2018/11/CreativeShrimp-logo-small.png
# 2 --> Creative Shrimp
# https://www.creativeshrimp.com/wp-content/uploads/2020/04/glitch-thumbnail_01_2-900x430.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/thumbnail_01_2-400x190.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/3drender_review_thumbnail_01_1-400x190.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/vlog_march_2020_thumbnail_01-400x190.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/03/blender_viewport_thumbnail_v3_01b-400x190.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/blender_viewport_thumbnail_v2_01-400x190.jpg
# 1 -->
# https://www.creativeshrimp.com/wp-content/uploads/2020/02/viewport_thumbnail_01_1a-400x190.jpg
# 1 -->
# ...
